# %% [markdown]
# ### **ISAAC NHYIRA KWAW APPIAH**
#
# ---
# ### **11234761**
#
# ---
# ### **BIOMEDICAL ENGINEERING**
# ---

# %% [markdown]
# ### **01.INTRODUCTION**
# ---
# In this case study, we will be analyzing a dataset on **red wine** samples.
#
# And consider the various variables involved and their effects on the red wine.

# %% [markdown]
# ### **02. ATTRIBUTE INFORMATION**
# ---
# Below are the variables we will be considering for the data analysis
#
# Input variables:
# - 1 - fixed acidity
# - 2 - volatile acidity
# - 3 - citric acid
# - 4 - residual sugar
# - 5 - chlorides
# - 6 - free sulfur dioxide
# - 7 - total sulfur dioxide
# - 8 - density
# - 9 - pH
# - 10 - sulphates
# - 11 - alcohol
#
# Output variable (based on sensory data):
# - 12 - quality ratings(score between 0 and 10)

# %% [markdown]
# ### **03. QUESTIONS TO BE ANSWERED**
# ---

# %% [markdown]
# 1. What is the **amount** of certain parameters found in the red wine?
# 2. How do certain parameters affect the **quality** of the red wine?
# 3. How do the various parameters affect the **pH** of the red wine?

# %% [markdown]
# ### **04. ASSESSING DATA**
# ---
# Here, we import the dataset we obtained.

# %% [markdown]
# #### **4.1 Importing Python libraries needed to analyze data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### **4.2 Importing Data**

# %%
dataset = pd.read_csv('red_wine.csv')
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# #### **4.3 Viewing first 10 sets of data**

# %%
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# #### **4.4 Viewing last 20 sets of data**

# %%
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %% [markdown]
# #### 4.5 Checking basic information on dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %% [markdown]
# #### 4.6 Checking statistical data on dataset

# %%
 dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
dataset.shape
# Out:
# (1599, 12)

# %%
dataset.ndim
# Out:
# 2

# %% [markdown]
# ### **05. APPENDING DATA**
# ---
# We will edit the data obtained to remove duplicated values and null parameters

# %% [markdown]
# #### **Checking and removing null sets**

# %%
dataset.isnull().sum()
# Out:
# fixed acidity           1
# volatile acidity        1
# citric acid             0
# residual sugar          0
# chlorides               4
# free sulfur dioxide     1
# total sulfur dioxide    0
# density                 1
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
dataset.dropna(inplace=True)
dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# #### **5.2 Checking and removing duplicated values**

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1590, dtype: bool

# %%
dataset.drop_duplicates()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1590 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1590 non-null   float64
#  1   volatile acidity      1590 non-null   float64
#  2   citric acid           1590 non-null   float64
#  3   residual sugar        1590 non-null   float64
#  4   chlorides             1590 non-null   float64
#  5   free sulfur dioxide   1590 non-null   float64
#  6   total sulfur dioxide  1590 non-null   float64
#  7   density               1590 non-null   float64
#  8   pH                    1590 non-null   float64
#  9   sulphates             1590 non-null   float64
#  10  alcohol               1590 non-null   float64
#  11  quality               1590 non-null   float64
# dtypes: float64(12)
# memory usage: 161.5 KB

# %% [markdown]
# ### **06. ANSWERING SET QUESTIONS**
# ---

# %% [markdown]
# #### **6.1 Checking for the various quantities of some attributes in the various samples of red wine**

# %%
dataset['total sulfur dioxide'].hist();

# %%
dataset['pH'].hist();

# %%
dataset['chlorides'].hist();

# %%
dataset['density'].hist();

# %% [markdown]
# #### **6.2 Checking effects of parameters on quality**

# %%
plt.scatter(dataset['alcohol'], dataset['quality'], color='red', alpha=0.5)
plt.title('Alcohol vs. Quality')
plt.xlabel('Alcohol')
plt.ylabel('Quality')
plt.grid(True)
plt.show()

# %%
plt.scatter(dataset['chlorides'], dataset['quality'], color='blue', alpha=0.5)
plt.title('Chlorides vs. Quality')
plt.xlabel('Chlorides')
plt.ylabel('Quality')
plt.grid(True)
plt.show()

# %%
plt.scatter(dataset['citric acid'], dataset['quality'], color='green', alpha=0.5)
plt.title('Citric Acid vs. Quality')
plt.xlabel('Citric Acid')
plt.ylabel('Quality')
plt.grid(True)
plt.show()

# %%
plt.scatter(dataset['residual sugar'], dataset['quality'], color='black', alpha=0.5)
plt.title('Residual Sugar vs. Quality')
plt.xlabel('Residual Sugar')
plt.ylabel('Quality')
plt.grid(True)
plt.show()

# %% [markdown]
# #### **6.3 Checking effects of acids on pH**

# %%
plt.scatter(dataset['fixed acidity'], dataset['pH'], color='gold', alpha=0.5)
plt.title('Fixed Acidity vs. pH')
plt.xlabel('Fixed Acidity')
plt.ylabel('pH')
plt.grid(True)
plt.show()

# %%
plt.scatter(dataset['volatile acidity'], dataset['pH'], color='magenta', alpha=0.5)
plt.title('Volatile Acidity vs pH')
plt.xlabel('Volatile Acidity')
plt.ylabel('pH')
plt.grid(True)
plt.show()

# %%
plt.scatter(dataset['citric acid'], dataset['pH'], color='brown', alpha=0.5)
plt.title('Citric Acid vs pH')
plt.xlabel('Citric Acid')
plt.ylabel('pH')
plt.grid(True)
plt.show()

# %%
plt.scatter(dataset['total sulfur dioxide'], dataset['pH'], color='cyan', alpha=0.5)
plt.title('Total Sulfur Dioxide vs pH')
plt.xlabel('Total Sulfur Dioxide')
plt.ylabel('pH')
plt.grid(True)
plt.show()

# %% [markdown]
# #### **6.4 Correlation of Results**

# %% [markdown]
# - #### From the histograms in Section 6.1, we can deduce that;
#
# i. The *amount of sulfur dioxide* found in the samples of red wine **ranges from 0 to 200** with an *average values* which **ranges from 0 to 50** and with *few samples* having sulfur dioxide **above 150**
#
# ii. The *pH of the samples* of red wine **ranges from 0 to a little over 4.0** with *average values* **ranging from 3.2 to 3.4** and and *few samples* having pH which fall **below 3.0** and **above 3.6**
#
# iii.The *amount of chlorides* found in the samples of red wine **ranges from 0 to 0.5** with *most samples* containing chlorides **ranging from 0 to 0.2** and only *a few samples* with clorides **above 0.2**
#
# iv. The samples of red wine were found to have **ranging densities** with *most samples* having densities **between 0.94 and 1**

# %% [markdown]
# - #### From the scatter diagrams in Section 6.2, we can deduce that;
#
# i. The *__quality__* of the red wine **increases** with an **increases** in its *alcohol content*
#
# ii. The *__quality__* of the red wine **increases** with a **decrease** in its *chloride content*
#
# iii. The *__quality__* of the red wine **increases** across values of *citric content* but more noticeable increase in quality for values **between 0.2 and 0.8**
#
# iv.The *__quality__* of the red wine **increases** with a **decrease** in its *residual sugar content*

# %% [markdown]
# - #### From the scatter diagrams in Section 6.3, we can deduce that;
#
# i. An **increase** in the *fixed acidity* **increases** the *pH* and makes it __*less acidic*__.
#
# ii. The *pH* stays in the **range from 2.8 to 3.8** with **increase** in *volatile acidity* with only *__few deviations__*.
#
# iii. An **increase** in the *citric acid* **decreases** the *pH* and makes it __*more acidic*__.
#
# iv. An **increase** in the *sulfur dioxide* content reduces the *pH* range **from 2.8 to 3.8**  to a *pH* range of **3.2 to 3.4** with a *__few deviations__*

# %% [markdown]
# ### **07. CONCLUSION**
# ---

# %% [markdown]
# Let's revisit our questions and include our observations from the analysis.
#
# 1. What is the amount of certain parameters found in the red wine?
# >Most red wine samples were found to contain low amounts of chlorides, high amounts of sulfur dioxide, ranging densities and a pH of less than 4
#
#
# 2. How do certain parameters affect the quality of the red wine?
#
# > The quality ratings of red wine increase with increase in its alcoholic content, decrease in both chloride content and residual sugar content and with citric acid content ranging between 0.2 and 0.8.
#
# 3. How do the various parameters affect the pH of the red wine?
#
# > The pH of the red wine increases mainly with an increase in fixed acidity (less acidic) and reduces mainly with an increase in citric acid content(more acidic).
#
#
# ##### **_Thank you for reading my analysis!_**
